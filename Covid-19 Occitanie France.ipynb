# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Covid-19-Occitanie-France" data-toc-modified-id="Covid-19-Occitanie-France-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Covid-19 Occitanie France</a></span></li></ul></div>

# %% [markdown]
# # Covid-19 Occitanie France

# %% [markdown]
# Initial Data

# %%
import pandas as pd
import plotly
import plotly.offline as py

from typing import List, Optional

from plotly import graph_objs as go
from plotly import figure_factory as ff
from plotly import tools
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
df = pd.read_csv('./Covid19OccitanieFrance.csv')
df
# Out:
#         Date  Positifs total  Hospitalization en cours  Dont reanimation  \
# 0   03/07/20              29                         1                 1
# 1   03/09/20              60                         2                 2
# 2   03/11/20             118                         8                 8
# 3   03/12/20             150                        11                11
# 4   03/13/20             175                        17                17
# 5   03/14/20             210                        17                17
# 6   03/15/20             254                        23                23
# 7   03/16/20             284                        23                23
# 8   03/17/20             313                        80                32
# 9   03/18/20             389                        99                37
# 10  03/19/20             472                       155                62
# 11  03/20/20             520                       185                67
# 12  03/21/20             611                       208                72
# 13  03/22/20             671                       293                86
# 14  03/23/20             781                       320                97
# 15  03/24/20             900                       380               123
# 16  03/25/20            1082                       463               145
# 17  03/26/20            1285                       551               176
# 18  03/27/20            1553                       622               186
# 19  03/28/20            1823                       697               210
# 20  03/29/20            2002                       798               227
# 21  03/30/20            2126                       846               263
# 22  03/31/20            2374                       887               278
# 23  04/01/20            2633                       910               293
# 24  04/02/20            2844                       983               321
# 25  04/03/20            3112                      1013               320
# 26  04/04/20            3338                      1001               326
# 27  04/05/20            3476                      1045               322
# 28  04/06/20            3553                      1065               333
# 29  04/07/20            3690                      1044               334
# 30  04/08/20            3877                      1009               328
# 31  04/09/20            4134                       997               323
# 32  04/10/20            4364                       962               314
# 33  04/11/20            4468                       925               292
# 34  04/12/20            4735                       951               291
# 35  04/13/20            4838                       976               287
# 36  04/14/20            4911                       962               275
# 37  04/15/20            5080                       913               262
# 38  04/16/20            5246                       873               254
# 39  04/17/20            5431                       871               240
# 40  04/18/20            5570                       861               238
# 41  04/19/20            5727                       878               242
# 42  04/20/20            5769                       895               231
# 43  04/21/20            5932                       876               217
# 44  04/22/20            6045                       855               210
#
#     Guerie  Deces
# 0        1      0
# 1        1      0
# 2        1      0
# 3        1      0
# 4        3      0
# 5        3      0
# 6        3      1
# 7        3      3
# 8        3      5
# 9        3     10
# 10       3     17
# 11       3     23
# 12       3     27
# 13     123     30
# 14     131     32
# 15     161     40
# 16     195     45
# 17     233     54
# 18     269     61
# 19     314     67
# 20     325     72
# 21     365     81
# 22     450     88
# 23     530    106
# 24     613    120
# 25     674    133
# 26     730    149
# 27     772    158
# 28     815    172
# 29     933    181
# 30    1010    195
# 31    1094    203
# 32    1202    222
# 33    1218    233
# 34    1306    239
# 35    1327    250
# 36    1377    266
# 37    1470    278
# 38    1541    281
# 39    1601    290
# 40    1690    292
# 41    1701    295
# 42    1741    313
# 43    1799    322
# 44    1843    328

# %%
positifs_actuellement = []
increase_positifs_actuellement = []
percentage_positifs_actuellement = []

hospitalises_en_cours = [int(h) for h in df[["Hospitalization en cours"]].values]
increase_hospitalises = []

positifs_non_hospitalises = []
increase_positifs_non_hospitalises = []

guerie_v = [int(g) for g in df[["Guerie"]].values]
increase_guerie = []

deces_v = [int(d) for d in df[["Deces"]].values]
increase_deces = []

c = 0
for index, row in df[["Positifs total", "Guerie", "Deces", "Hospitalization en cours"]].iterrows():
    positfs_total = row[0]
    guerie = row[1]
    deces = row[2]
    hospitalises = row[3]
    positifs_actuellement_ = positfs_total - guerie - deces
    positifs_actuellement.append(positifs_actuellement_)
    
    positifs_non_hospitalises.append(positifs_actuellement_ - hospitalises)

    if c == 0:
        increase_positifs_actuellement.append(positifs_actuellement[c])
        
        increase_positifs_non_hospitalises.append(increase_positifs_actuellement[c])
        
        increase_hospitalises.append(hospitalises_en_cours[c])
        increase_guerie.append(guerie_v[c])
        increase_deces.append(deces_v[c])
    else:
        increase_positifs_actuellement.append(positifs_actuellement[c] - positifs_actuellement[c - 1])
        
        increase_positifs_non_hospitalises.append(
            increase_positifs_actuellement[c] - increase_positifs_actuellement[c - 1])
        
        increase_hospitalises.append(hospitalises_en_cours[c] - hospitalises_en_cours[c - 1])
        increase_guerie.append(guerie_v[c] - guerie_v[c - 1])
        increase_deces.append(deces_v[c] - deces_v[c - 1])
        
    percentage_positifs_actuellement.append(increase_positifs_actuellement[c]/positifs_actuellement[c]*100)
    
    c += 1

df["Positifs actuellement"] = positifs_actuellement
df["Increase Positifs actuellement"] = increase_positifs_actuellement
df["Percentage Increase Positifs actuellement"] = percentage_positifs_actuellement

df["Increase Guerie"] = increase_guerie

df["Increase Deces"] = increase_deces

df["Increase hospitalisés"] = increase_hospitalises

df["Positifs non hospitalisés"] = positifs_non_hospitalises
df["Increase Positifs non hospitalisés"] = increase_positifs_non_hospitalises

df
# Out:
#         Date  Positifs total  Hospitalization en cours  Dont reanimation  \
# 0   03/07/20              29                         1                 1
# 1   03/09/20              60                         2                 2
# 2   03/11/20             118                         8                 8
# 3   03/12/20             150                        11                11
# 4   03/13/20             175                        17                17
# 5   03/14/20             210                        17                17
# 6   03/15/20             254                        23                23
# 7   03/16/20             284                        23                23
# 8   03/17/20             313                        80                32
# 9   03/18/20             389                        99                37
# 10  03/19/20             472                       155                62
# 11  03/20/20             520                       185                67
# 12  03/21/20             611                       208                72
# 13  03/22/20             671                       293                86
# 14  03/23/20             781                       320                97
# 15  03/24/20             900                       380               123
# 16  03/25/20            1082                       463               145
# 17  03/26/20            1285                       551               176
# 18  03/27/20            1553                       622               186
# 19  03/28/20            1823                       697               210
# 20  03/29/20            2002                       798               227
# 21  03/30/20            2126                       846               263
# 22  03/31/20            2374                       887               278
# 23  04/01/20            2633                       910               293
# 24  04/02/20            2844                       983               321
# 25  04/03/20            3112                      1013               320
# 26  04/04/20            3338                      1001               326
# 27  04/05/20            3476                      1045               322
# 28  04/06/20            3553                      1065               333
# 29  04/07/20            3690                      1044               334
# 30  04/08/20            3877                      1009               328
# 31  04/09/20            4134                       997               323
# 32  04/10/20            4364                       962               314
# 33  04/11/20            4468                       925               292
# 34  04/12/20            4735                       951               291
# 35  04/13/20            4838                       976               287
# 36  04/14/20            4911                       962               275
# 37  04/15/20            5080                       913               262
# 38  04/16/20            5246                       873               254
# 39  04/17/20            5431                       871               240
# 40  04/18/20            5570                       861               238
# 41  04/19/20            5727                       878               242
# 42  04/20/20            5769                       895               231
# 43  04/21/20            5932                       876               217
# 44  04/22/20            6045                       855               210
#
#     Guerie  Deces  Positifs actuellement  Increase Positifs actuellement  \
# 0        1      0                     28                              28
# 1        1      0                     59                              31
# 2        1      0                    117                              58
# 3        1      0                    149                              32
# 4        3      0                    172                              23
# 5        3      0                    207                              35
# 6        3      1                    250                              43
# 7        3      3                    278                              28
# 8        3      5                    305                              27
# 9        3     10                    376                              71
# 10       3     17                    452                              76
# 11       3     23                    494                              42
# 12       3     27                    581                              87
# 13     123     30                    518                             -63
# 14     131     32                    618                             100
# 15     161     40                    699                              81
# 16     195     45                    842                             143
# 17     233     54                    998                             156
# 18     269     61                   1223                             225
# 19     314     67                   1442                             219
# 20     325     72                   1605                             163
# 21     365     81                   1680                              75
# 22     450     88                   1836                             156
# 23     530    106                   1997                             161
# 24     613    120                   2111                             114
# 25     674    133                   2305                             194
# 26     730    149                   2459                             154
# 27     772    158                   2546                              87
# 28     815    172                   2566                              20
# 29     933    181                   2576                              10
# 30    1010    195                   2672                              96
# 31    1094    203                   2837                             165
# 32    1202    222                   2940                             103
# 33    1218    233                   3017                              77
# 34    1306    239                   3190                             173
# 35    1327    250                   3261                              71
# 36    1377    266                   3268                               7
# 37    1470    278                   3332                              64
# 38    1541    281                   3424                              92
# 39    1601    290                   3540                             116
# 40    1690    292                   3588                              48
# 41    1701    295                   3731                             143
# 42    1741    313                   3715                             -16
# 43    1799    322                   3811                              96
# 44    1843    328                   3874                              63
#
#     Percentage Increase Positifs actuellement  Increase Guerie  \
# 0                                  100.000000                1
# 1                                   52.542373                0
# 2                                   49.572650                0
# 3                                   21.476510                0
# 4                                   13.372093                2
# 5                                   16.908213                0
# 6                                   17.200000                0
# 7                                   10.071942                0
# 8                                    8.852459                0
# 9                                   18.882979                0
# 10                                  16.814159                0
# 11                                   8.502024                0
# 12                                  14.974182                0
# 13                                 -12.162162              120
# 14                                  16.181230                8
# 15                                  11.587983               30
# 16                                  16.983373               34
# 17                                  15.631263               38
# 18                                  18.397383               36
# 19                                  15.187240               45
# 20                                  10.155763               11
# 21                                   4.464286               40
# 22                                   8.496732               85
# 23                                   8.062093               80
# 24                                   5.400284               83
# 25                                   8.416486               61
# 26                                   6.262708               56
# 27                                   3.417125               42
# 28                                   0.779423               43
# 29                                   0.388199              118
# 30                                   3.592814               77
# 31                                   5.816003               84
# 32                                   3.503401              108
# 33                                   2.552204               16
# 34                                   5.423197               88
# 35                                   2.177246               21
# 36                                   0.214198               50
# 37                                   1.920768               93
# 38                                   2.686916               71
# 39                                   3.276836               60
# 40                                   1.337793               89
# 41                                   3.832753               11
# 42                                  -0.430686               40
# 43                                   2.519024               58
# 44                                   1.626226               44
#
#     Increase Deces  Increase hospitalisés  Positifs non hospitalisés  \
# 0                0                      1                         27
# 1                0                      1                         57
# 2                0                      6                        109
# 3                0                      3                        138
# 4                0                      6                        155
# 5                0                      0                        190
# 6                1                      6                        227
# 7                2                      0                        255
# 8                2                     57                        225
# 9                5                     19                        277
# 10               7                     56                        297
# 11               6                     30                        309
# 12               4                     23                        373
# 13               3                     85                        225
# 14               2                     27                        298
# 15               8                     60                        319
# 16               5                     83                        379
# 17               9                     88                        447
# 18               7                     71                        601
# 19               6                     75                        745
# 20               5                    101                        807
# 21               9                     48                        834
# 22               7                     41                        949
# 23              18                     23                       1087
# 24              14                     73                       1128
# 25              13                     30                       1292
# 26              16                    -12                       1458
# 27               9                     44                       1501
# 28              14                     20                       1501
# 29               9                    -21                       1532
# 30              14                    -35                       1663
# 31               8                    -12                       1840
# 32              19                    -35                       1978
# 33              11                    -37                       2092
# 34               6                     26                       2239
# 35              11                     25                       2285
# 36              16                    -14                       2306
# 37              12                    -49                       2419
# 38               3                    -40                       2551
# 39               9                     -2                       2669
# 40               2                    -10                       2727
# 41               3                     17                       2853
# 42              18                     17                       2820
# 43               9                    -19                       2935
# 44               6                    -21                       3019
#
#     Increase Positifs non hospitalisés
# 0                                   28
# 1                                    3
# 2                                   27
# 3                                  -26
# 4                                   -9
# 5                                   12
# 6                                    8
# 7                                  -15
# 8                                   -1
# 9                                   44
# 10                                   5
# 11                                 -34
# 12                                  45
# 13                                -150
# 14                                 163
# 15                                 -19
# 16                                  62
# 17                                  13
# 18                                  69
# 19                                  -6
# 20                                 -56
# 21                                 -88
# 22                                  81
# 23                                   5
# 24                                 -47
# 25                                  80
# 26                                 -40
# 27                                 -67
# 28                                 -67
# 29                                 -10
# 30                                  86
# 31                                  69
# 32                                 -62
# 33                                 -26
# 34                                  96
# 35                                -102
# 36                                 -64
# 37                                  57
# 38                                  28
# 39                                  24
# 40                                 -68
# 41                                  95
# 42                                -159
# 43                                 112
# 44                                 -33

# %%
df = df[df["Date"] >= "04/01/20"]

# %%
def create_2d_plot(plot_df: pd.DataFrame, x_name: str, y_name: str, fig: Optional[go.Figure] = None):
    """Create 2D plot."""
    trace = go.Scatter(
        x=plot_df[x_name],
        y=plot_df[y_name],
        mode="lines+markers",
        marker=dict(
            size=6,
            color=[float(n) for n in plot_df[y_name].values],  # set color to an array/list of desired values
            opacity=0.8,
        ),
        name=y_name,
    )
    
    annotations = []
    c = 0

    for (x, y) in zip(plot_df[x_name], plot_df[y_name]):
        annotations.append(
            dict(
                showarrow=False,
                x=x,
                y=y,
                text=str(plot_df[y_name].values[c]),
                xanchor="left",
                xshift=15,
                opacity=0.7,
            )
        )
        c += 1
   
    return trace, annotations

# %%
trace1, annotations1 = create_2d_plot(plot_df=df, x_name="Date", y_name="Positifs total")
trace2, annotations2 = create_2d_plot(plot_df=df, x_name="Date", y_name="Positifs actuellement")

data = [trace1, trace2]

annotations = [annotations1[len(annotations1) - 1]] + [annotations2[len(annotations2) - 1]]

layout = go.Layout(
    title=f"Covid19-France-Occitanie Positifs total vs Positifs actuels",
    xaxis=dict(title="Time"),
    legend=dict(orientation="h", y = -0.3, yanchor="top"),
    annotations=annotations,
    showlegend=True,
) 
fig = go.Figure(data=data, layout=layout)
    
iplot(fig, filename="covid19-Occitanie")
# Out:
# <div id="84fcad17-afa8-425b-a706-12297b7f1d4d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("84fcad17-afa8-425b-a706-12297b7f1d4d", [{"marker": {"color": [2633.0, 2844.0, 3112.0, 3338.0, 3476.0, 3553.0, 3690.0, 3877.0, 4134.0, 4364.0, 4468.0, 4735.0, 4838.0, 4911.0, 5080.0, 5246.0, 5431.0, 5570.0, 5727.0, 5769.0, 5932.0, 6045.0], "opacity": 0.8, "size": 6}, "mode": "lines+markers", "name": "Positifs total", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [2633, 2844, 3112, 3338, 3476, 3553, 3690, 3877, 4134, 4364, 4468, 4735, 4838, 4911, 5080, 5246, 5431, 5570, 5727, 5769, 5932, 6045], "type": "scatter", "uid": "58d1d61d-d6ea-45e8-a695-92971eb8e25c"}, {"marker": {"color": [1997.0, 2111.0, 2305.0, 2459.0, 2546.0, 2566.0, 2576.0, 2672.0, 2837.0, 2940.0, 3017.0, 3190.0, 3261.0, 3268.0, 3332.0, 3424.0, 3540.0, 3588.0, 3731.0, 3715.0, 3811.0, 3874.0], "opacity": 0.8, "size": 6}, "mode": "lines+markers", "name": "Positifs actuellement", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [1997, 2111, 2305, 2459, 2546, 2566, 2576, 2672, 2837, 2940, 3017, 3190, 3261, 3268, 3332, 3424, 3540, 3588, 3731, 3715, 3811, 3874], "type": "scatter", "uid": "c6f5148a-eec8-485a-9de4-3b3899362c8f"}], {"annotations": [{"opacity": 0.7, "showarrow": false, "text": "6045", "x": "04/22/20", "xanchor": "left", "xshift": 15, "y": 6045}, {"opacity": 0.7, "showarrow": false, "text": "3874", "x": "04/22/20", "xanchor": "left", "xshift": 15, "y": 3874}], "legend": {"orientation": "h", "y": -0.3, "yanchor": "top"}, "showlegend": true, "title": {"text": "Covid19-France-Occitanie Positifs total vs Positifs actuels"}, "xaxis": {"title": {"text": "Time"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("84fcad17-afa8-425b-a706-12297b7f1d4d"));});</script>

# %%
trace, annotations = create_2d_plot(plot_df=df, x_name="Date", y_name="Increase Positifs actuellement")

data = [trace]

layout = go.Layout(
    title=f"Covid19-France-Occitanie Increase positifs actuel",
    xaxis=dict(title="Time"),
    yaxis=dict(title="Increase Positive actuellement [%]"),
    annotations=annotations,
    showlegend=True,
    legend=dict(orientation="h", y = -0.3, yanchor="top"),
)
fig = go.Figure(data=data, layout=layout)
    
iplot(fig, filename="covid19-Occitanie")
# Out:
# <div id="21c47bf4-021f-4e45-8896-44e788d014af" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("21c47bf4-021f-4e45-8896-44e788d014af", [{"marker": {"color": [161.0, 114.0, 194.0, 154.0, 87.0, 20.0, 10.0, 96.0, 165.0, 103.0, 77.0, 173.0, 71.0, 7.0, 64.0, 92.0, 116.0, 48.0, 143.0, -16.0, 96.0, 63.0], "opacity": 0.8, "size": 6}, "mode": "lines+markers", "name": "Increase Positifs actuellement", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [161, 114, 194, 154, 87, 20, 10, 96, 165, 103, 77, 173, 71, 7, 64, 92, 116, 48, 143, -16, 96, 63], "type": "scatter", "uid": "2db9612b-7119-475c-aaea-d166ade9e17b"}], {"annotations": [{"opacity": 0.7, "showarrow": false, "text": "161", "x": "04/01/20", "xanchor": "left", "xshift": 15, "y": 161}, {"opacity": 0.7, "showarrow": false, "text": "114", "x": "04/02/20", "xanchor": "left", "xshift": 15, "y": 114}, {"opacity": 0.7, "showarrow": false, "text": "194", "x": "04/03/20", "xanchor": "left", "xshift": 15, "y": 194}, {"opacity": 0.7, "showarrow": false, "text": "154", "x": "04/04/20", "xanchor": "left", "xshift": 15, "y": 154}, {"opacity": 0.7, "showarrow": false, "text": "87", "x": "04/05/20", "xanchor": "left", "xshift": 15, "y": 87}, {"opacity": 0.7, "showarrow": false, "text": "20", "x": "04/06/20", "xanchor": "left", "xshift": 15, "y": 20}, {"opacity": 0.7, "showarrow": false, "text": "10", "x": "04/07/20", "xanchor": "left", "xshift": 15, "y": 10}, {"opacity": 0.7, "showarrow": false, "text": "96", "x": "04/08/20", "xanchor": "left", "xshift": 15, "y": 96}, {"opacity": 0.7, "showarrow": false, "text": "165", "x": "04/09/20", "xanchor": "left", "xshift": 15, "y": 165}, {"opacity": 0.7, "showarrow": false, "text": "103", "x": "04/10/20", "xanchor": "left", "xshift": 15, "y": 103}, {"opacity": 0.7, "showarrow": false, "text": "77", "x": "04/11/20", "xanchor": "left", "xshift": 15, "y": 77}, {"opacity": 0.7, "showarrow": false, "text": "173", "x": "04/12/20", "xanchor": "left", "xshift": 15, "y": 173}, {"opacity": 0.7, "showarrow": false, "text": "71", "x": "04/13/20", "xanchor": "left", "xshift": 15, "y": 71}, {"opacity": 0.7, "showarrow": false, "text": "7", "x": "04/14/20", "xanchor": "left", "xshift": 15, "y": 7}, {"opacity": 0.7, "showarrow": false, "text": "64", "x": "04/15/20", "xanchor": "left", "xshift": 15, "y": 64}, {"opacity": 0.7, "showarrow": false, "text": "92", "x": "04/16/20", "xanchor": "left", "xshift": 15, "y": 92}, {"opacity": 0.7, "showarrow": false, "text": "116", "x": "04/17/20", "xanchor": "left", "xshift": 15, "y": 116}, {"opacity": 0.7, "showarrow": false, "text": "48", "x": "04/18/20", "xanchor": "left", "xshift": 15, "y": 48}, {"opacity": 0.7, "showarrow": false, "text": "143", "x": "04/19/20", "xanchor": "left", "xshift": 15, "y": 143}, {"opacity": 0.7, "showarrow": false, "text": "-16", "x": "04/20/20", "xanchor": "left", "xshift": 15, "y": -16}, {"opacity": 0.7, "showarrow": false, "text": "96", "x": "04/21/20", "xanchor": "left", "xshift": 15, "y": 96}, {"opacity": 0.7, "showarrow": false, "text": "63", "x": "04/22/20", "xanchor": "left", "xshift": 15, "y": 63}], "legend": {"orientation": "h", "y": -0.3, "yanchor": "top"}, "showlegend": true, "title": {"text": "Covid19-France-Occitanie Increase positifs actuel"}, "xaxis": {"title": {"text": "Time"}}, "yaxis": {"title": {"text": "Increase Positive actuellement [%]"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("21c4 ...

# %%
trace_guerie, a2 = create_2d_plot(plot_df=df, x_name="Date", y_name="Increase Guerie")

data = [trace_guerie]

layout = go.Layout(
    title=f"CovidOccitanieFrance-2Dplot-Guerie",
    xaxis=dict(title="Time"),
    yaxis=dict(title="Guerie"),
    showlegend=True,
) 
fig = go.Figure(data=data, layout=layout)
    
iplot(fig, filename="covid19-Occitanie")
# Out:
# <div id="e7c27fb2-6c00-46a0-abe0-d1fb8081e890" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e7c27fb2-6c00-46a0-abe0-d1fb8081e890", [{"marker": {"color": [80.0, 83.0, 61.0, 56.0, 42.0, 43.0, 118.0, 77.0, 84.0, 108.0, 16.0, 88.0, 21.0, 50.0, 93.0, 71.0, 60.0, 89.0, 11.0, 40.0, 58.0, 44.0], "opacity": 0.8, "size": 6}, "mode": "lines+markers", "name": "Increase Guerie", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [80, 83, 61, 56, 42, 43, 118, 77, 84, 108, 16, 88, 21, 50, 93, 71, 60, 89, 11, 40, 58, 44], "type": "scatter", "uid": "1d5b174d-920d-4e90-8982-5d1ffb00e185"}], {"showlegend": true, "title": {"text": "CovidOccitanieFrance-2Dplot-Guerie"}, "xaxis": {"title": {"text": "Time"}}, "yaxis": {"title": {"text": "Guerie"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("e7c27fb2-6c00-46a0-abe0-d1fb8081e890"));});</script>

# %%
trace_deces, a2 = create_2d_plot(plot_df=df, x_name="Date", y_name="Increase Deces")

data = [trace_deces]

layout = go.Layout(
    title=f"CovidOccitanieFrance-2Dplot-Deces",
    xaxis=dict(title="Time"),
    yaxis=dict(title="Deces"),
    showlegend=True,
) 
fig = go.Figure(data=data, layout=layout)
    
iplot(fig, filename="covid19-Occitanie")
# Out:
# <div id="7c3338e4-a5b4-497b-ac36-67c88f130912" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7c3338e4-a5b4-497b-ac36-67c88f130912", [{"marker": {"color": [18.0, 14.0, 13.0, 16.0, 9.0, 14.0, 9.0, 14.0, 8.0, 19.0, 11.0, 6.0, 11.0, 16.0, 12.0, 3.0, 9.0, 2.0, 3.0, 18.0, 9.0, 6.0], "opacity": 0.8, "size": 6}, "mode": "lines+markers", "name": "Increase Deces", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [18, 14, 13, 16, 9, 14, 9, 14, 8, 19, 11, 6, 11, 16, 12, 3, 9, 2, 3, 18, 9, 6], "type": "scatter", "uid": "2c7964e2-23a3-4ba9-959c-0914c93781e3"}], {"showlegend": true, "title": {"text": "CovidOccitanieFrance-2Dplot-Deces"}, "xaxis": {"title": {"text": "Time"}}, "yaxis": {"title": {"text": "Deces"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("7c3338e4-a5b4-497b-ac36-67c88f130912"));});</script>

# %%
trace_positive, annotations1 = create_2d_plot(plot_df=df, x_name="Date", y_name="Positifs total")
trace_positive_a, annotations2 = create_2d_plot(plot_df=df, x_name="Date", y_name="Positifs actuellement")
trace_positive_maison, annotations3 = create_2d_plot(plot_df=df, x_name="Date", y_name="Positifs non hospitalisés")
trace_positive_hopital, annotations4 = create_2d_plot(plot_df=df, x_name="Date", y_name="Hospitalization en cours")
trace_positive_hopital_reanimation, annotations5 = create_2d_plot(plot_df=df, x_name="Date", y_name="Dont reanimation")
trace_guerie, annotations6 = create_2d_plot(plot_df=df, x_name="Date", y_name="Guerie")
trace_deces, annotations7 = create_2d_plot(plot_df=df, x_name="Date", y_name="Deces")

data = [trace_positive, trace_positive_a, trace_positive_maison, trace_positive_hopital, trace_positive_hopital_reanimation, trace_guerie, trace_deces]

annotations = annotations1[len(annotations1) - 1:] \
    + annotations2[len(annotations2) - 1:] \
    + annotations3[len(annotations3) - 1:] \
    + annotations4[len(annotations4) - 1:] \
    + annotations5[len(annotations5) - 1:] \
    + annotations6[len(annotations6) - 1:] \
    + annotations7[len(annotations7) - 1:]

layout = go.Layout(
    title=f"CovidOccitanieFrance",
    xaxis=dict(title="Time"),
#     yaxis=dict(title="),
    annotations=annotations,
    showlegend=True,
    legend=dict(orientation="h", y = -0.3, yanchor="top")
) 
fig = go.Figure(data=data, layout=layout)
    
iplot(fig, filename="covid19-Occitanie")
# Out:
# <div id="95fc6bb0-121e-4954-ab4e-b4effda31c7a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("95fc6bb0-121e-4954-ab4e-b4effda31c7a", [{"marker": {"color": [2633.0, 2844.0, 3112.0, 3338.0, 3476.0, 3553.0, 3690.0, 3877.0, 4134.0, 4364.0, 4468.0, 4735.0, 4838.0, 4911.0, 5080.0, 5246.0, 5431.0, 5570.0, 5727.0, 5769.0, 5932.0, 6045.0], "opacity": 0.8, "size": 6}, "mode": "lines+markers", "name": "Positifs total", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [2633, 2844, 3112, 3338, 3476, 3553, 3690, 3877, 4134, 4364, 4468, 4735, 4838, 4911, 5080, 5246, 5431, 5570, 5727, 5769, 5932, 6045], "type": "scatter", "uid": "e26452d3-dca5-47f3-8dd5-6af1c3e57adf"}, {"marker": {"color": [1997.0, 2111.0, 2305.0, 2459.0, 2546.0, 2566.0, 2576.0, 2672.0, 2837.0, 2940.0, 3017.0, 3190.0, 3261.0, 3268.0, 3332.0, 3424.0, 3540.0, 3588.0, 3731.0, 3715.0, 3811.0, 3874.0], "opacity": 0.8, "size": 6}, "mode": "lines+markers", "name": "Positifs actuellement", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [1997, 2111, 2305, 2459, 2546, 2566, 2576, 2672, 2837, 2940, 3017, 3190, 3261, 3268, 3332, 3424, 3540, 3588, 3731, 3715, 3811, 3874], "type": "scatter", "uid": "52ef2b95-c94e-4c50-8dae-284343d2fe12"}, {"marker": {"color": [1087.0, 1128.0, 1292.0, 1458.0, 1501.0, 1501.0, 1532.0, 1663.0, 1840.0, 1978.0, 2092.0, 2239.0, 2285.0, 2306.0, 2419.0, 2551.0, 2669.0, 2727.0, 2853.0, 2820.0, 2935.0, 3019.0], "opacity": 0.8, "size": 6}, "mode": "lines+markers", "name": "Positifs non hospitalis\u00e9s", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [1087, 1128, 1292, 1458, 1501, 1501, 1532, 1663, 1840, 1978, 2092, 2239, 2285, 2306, 2419, 2551, 2669, 2727, 2853, 2820, 2935, 3019], "type": "scatter", "uid": "3892186b-a5e1-4479-8d42-362f34ba2635"}, {"marker": {"color": [910.0, 983.0, 1013.0, 1001.0, 1045.0, 1065.0, 1044.0, 1009.0, 997.0, 962.0, 925.0, 951.0, 976.0, 962.0, 913.0, 873.0, 871.0, 861.0, 878.0, 895.0, 876.0, 855.0], "opacity": 0.8, "size": 6}, "mode": "lines+markers", "name": "Hospitalization en cours", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [910, 983, 1013, 1001, 1045, 1065, 1044, 1009, 997, 962, 925, 951, 976, 962, 913, 873, 871, 861, 878, 895, 876, 855], "type": "scatter", "uid": "e4d21d16-a5d2-4641-bf50-c1f8da6ce482"}, {"marker": {"color": [293.0, 321.0, 320.0, 326.0, 322.0, 333.0, 334.0, 328.0, 323.0, 314.0, 292.0, 291.0, 287.0, 275.0, 262.0, 254.0, 240.0, 238.0, 242.0, 231.0, 217.0, 210.0], "opacity": 0.8, "size": 6}, "mode": "lines+markers", "name": "Dont reanimation", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [293, 321, 320, 326, 322, 333, 334, 328, 323, 314, 292, 291, 287, 275, 262, 254, 240, 238, 242, 231, 217, 210], "type": " ...

# %%
dates=df["Date"].values

layout = go.Layout(
    barmode='group',
    title=f"Covid19-France-Occitanie",
    xaxis=dict(title="Time"),
    showlegend=True,
) 
fig = go.Figure(data=[
    go.Bar(name="Deces", x=dates, y=df["Deces"], text=df["Deces"],
            textposition='auto'),
    go.Bar(name="Gueries", x=dates, y=df["Guerie"], text=df["Guerie"],
            textposition='auto'),
    go.Bar(name="Positifs total", x=dates, y=df["Positifs total"], text=df["Positifs total"],
            textposition='auto'),

],
    layout=layout
)

iplot(fig, filename="covid19-Occitanie1")
# Out:
# <div id="1cca8a20-e9fe-4b7d-94c4-f7489f82e86e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1cca8a20-e9fe-4b7d-94c4-f7489f82e86e", [{"name": "Deces", "text": [106.0, 120.0, 133.0, 149.0, 158.0, 172.0, 181.0, 195.0, 203.0, 222.0, 233.0, 239.0, 250.0, 266.0, 278.0, 281.0, 290.0, 292.0, 295.0, 313.0, 322.0, 328.0], "textposition": "auto", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [106, 120, 133, 149, 158, 172, 181, 195, 203, 222, 233, 239, 250, 266, 278, 281, 290, 292, 295, 313, 322, 328], "type": "bar", "uid": "1e9029d8-5d73-4d88-9a45-7199c32394f2"}, {"name": "Gueries", "text": [530.0, 613.0, 674.0, 730.0, 772.0, 815.0, 933.0, 1010.0, 1094.0, 1202.0, 1218.0, 1306.0, 1327.0, 1377.0, 1470.0, 1541.0, 1601.0, 1690.0, 1701.0, 1741.0, 1799.0, 1843.0], "textposition": "auto", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [530, 613, 674, 730, 772, 815, 933, 1010, 1094, 1202, 1218, 1306, 1327, 1377, 1470, 1541, 1601, 1690, 1701, 1741, 1799, 1843], "type": "bar", "uid": "eeda5b52-4879-442f-8191-05197a492ae7"}, {"name": "Positifs total", "text": [2633.0, 2844.0, 3112.0, 3338.0, 3476.0, 3553.0, 3690.0, 3877.0, 4134.0, 4364.0, 4468.0, 4735.0, 4838.0, 4911.0, 5080.0, 5246.0, 5431.0, 5570.0, 5727.0, 5769.0, 5932.0, 6045.0], "textposition": "auto", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [2633, 2844, 3112, 3338, 3476, 3553, 3690, 3877, 4134, 4364, 4468, 4735, 4838, 4911, 5080, 5246, 5431, 5570, 5727, 5769, 5932, 6045], "type": "bar", "uid": "9892d8df-0275-44c7-8a1f-6a6db108f6cd"}], {"barmode": "group", "showlegend": true, "title": {"text": "Covid19-France-Occitanie"}, "xaxis": {"title": {"text": "Time"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("1cca8a20-e9fe-4b7d-94c4-f7489f82e86e"));});</script>

# %%
dates=df["Date"].values

layout = go.Layout(
    barmode='group',
    title=f"Covid19-France-Occitanie",
    xaxis=dict(title="Time"),
    showlegend=True,
    legend=dict(orientation="h", y = -0.3, yanchor="top")
) 
fig = go.Figure(data=[
    go.Bar(name="Hospitalisés", x=dates, y=df["Hospitalization en cours"], text=df["Hospitalization en cours"],
            textposition='auto'),
    go.Bar(name="Positifs non hospitalisés", x=dates, y=df["Positifs non hospitalisés"], text=df["Positifs non hospitalisés"],
            textposition='auto'),
    go.Bar(name="Positifs actuellement", x=dates, y=df["Positifs actuellement"], text=df["Positifs actuellement"],
            textposition='auto'),
],
    layout=layout
)

iplot(fig, filename="Covid19-France-Occitanie")
# Out:
# <div id="38a2438b-d5a1-43fb-9f66-70f18c9b33ac" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("38a2438b-d5a1-43fb-9f66-70f18c9b33ac", [{"name": "Hospitalis\u00e9s", "text": [910.0, 983.0, 1013.0, 1001.0, 1045.0, 1065.0, 1044.0, 1009.0, 997.0, 962.0, 925.0, 951.0, 976.0, 962.0, 913.0, 873.0, 871.0, 861.0, 878.0, 895.0, 876.0, 855.0], "textposition": "auto", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [910, 983, 1013, 1001, 1045, 1065, 1044, 1009, 997, 962, 925, 951, 976, 962, 913, 873, 871, 861, 878, 895, 876, 855], "type": "bar", "uid": "63894fea-3cad-4506-8899-fc7896a73990"}, {"name": "Positifs non hospitalis\u00e9s", "text": [1087.0, 1128.0, 1292.0, 1458.0, 1501.0, 1501.0, 1532.0, 1663.0, 1840.0, 1978.0, 2092.0, 2239.0, 2285.0, 2306.0, 2419.0, 2551.0, 2669.0, 2727.0, 2853.0, 2820.0, 2935.0, 3019.0], "textposition": "auto", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [1087, 1128, 1292, 1458, 1501, 1501, 1532, 1663, 1840, 1978, 2092, 2239, 2285, 2306, 2419, 2551, 2669, 2727, 2853, 2820, 2935, 3019], "type": "bar", "uid": "6613238f-04d1-4de4-a1e4-68000fd1bb16"}, {"name": "Positifs actuellement", "text": [1997.0, 2111.0, 2305.0, 2459.0, 2546.0, 2566.0, 2576.0, 2672.0, 2837.0, 2940.0, 3017.0, 3190.0, 3261.0, 3268.0, 3332.0, 3424.0, 3540.0, 3588.0, 3731.0, 3715.0, 3811.0, 3874.0], "textposition": "auto", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [1997, 2111, 2305, 2459, 2546, 2566, 2576, 2672, 2837, 2940, 3017, 3190, 3261, 3268, 3332, 3424, 3540, 3588, 3731, 3715, 3811, 3874], "type": "bar", "uid": "90862e84-808d-458f-8ff8-98fef5f042fa"}], {"barmode": "group", "legend": {"orientation": "h", "y": -0.3, "yanchor": "top"}, "showlegend": true, "title": {"text": "Covid19-France-Occitanie"}, "xaxis": {"title": {"text": "Time"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("38a2438b-d5a1-43fb-9f66-70f18c9b33ac"));});</script>

# %%
dates=df["Date"].values

layout = go.Layout(
    barmode='stack',
    title=f"CovidOccitanieFrance",
    xaxis=dict(title="Time"),
    showlegend=True,
) 
fig = go.Figure(data=[
    go.Bar(name="Positive actuellement", x=dates, y=df["Positifs actuellement"], text=df["Positifs actuellement"],
            textposition='auto'),
    go.Bar(name="Hospitalize", x=dates, y=df["Hospitalization en cours"], text=df["Hospitalization en cours"],
            textposition='auto'),
    go.Bar(name="Reanimation", x=dates, y=df["Dont reanimation"], text=df["Dont reanimation"],
            textposition='auto'),
    go.Bar(name="Positifs non hospitalisés", x=dates, y=df["Positifs non hospitalisés"], text=df["Positifs non hospitalisés"],
            textposition='auto'),
],
    layout=layout
)

iplot(fig, filename="covid19-Occitanie2")
# Out:
# <div id="fb73edaa-115e-4768-8c9b-c4d948052bb2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fb73edaa-115e-4768-8c9b-c4d948052bb2", [{"name": "Positive actuellement", "text": [1997.0, 2111.0, 2305.0, 2459.0, 2546.0, 2566.0, 2576.0, 2672.0, 2837.0, 2940.0, 3017.0, 3190.0, 3261.0, 3268.0, 3332.0, 3424.0, 3540.0, 3588.0, 3731.0, 3715.0, 3811.0, 3874.0], "textposition": "auto", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [1997, 2111, 2305, 2459, 2546, 2566, 2576, 2672, 2837, 2940, 3017, 3190, 3261, 3268, 3332, 3424, 3540, 3588, 3731, 3715, 3811, 3874], "type": "bar", "uid": "8f1a73c9-fc23-4dea-aa62-345e23d61434"}, {"name": "Hospitalize", "text": [910.0, 983.0, 1013.0, 1001.0, 1045.0, 1065.0, 1044.0, 1009.0, 997.0, 962.0, 925.0, 951.0, 976.0, 962.0, 913.0, 873.0, 871.0, 861.0, 878.0, 895.0, 876.0, 855.0], "textposition": "auto", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [910, 983, 1013, 1001, 1045, 1065, 1044, 1009, 997, 962, 925, 951, 976, 962, 913, 873, 871, 861, 878, 895, 876, 855], "type": "bar", "uid": "fc41be7d-ebdb-40bc-96b2-ae7f49708624"}, {"name": "Reanimation", "text": [293.0, 321.0, 320.0, 326.0, 322.0, 333.0, 334.0, 328.0, 323.0, 314.0, 292.0, 291.0, 287.0, 275.0, 262.0, 254.0, 240.0, 238.0, 242.0, 231.0, 217.0, 210.0], "textposition": "auto", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [293, 321, 320, 326, 322, 333, 334, 328, 323, 314, 292, 291, 287, 275, 262, 254, 240, 238, 242, 231, 217, 210], "type": "bar", "uid": "61af34e0-3db9-4404-b2ff-2278b0a6546b"}, {"name": "Positifs non hospitalis\u00e9s", "text": [1087.0, 1128.0, 1292.0, 1458.0, 1501.0, 1501.0, 1532.0, 1663.0, 1840.0, 1978.0, 2092.0, 2239.0, 2285.0, 2306.0, 2419.0, 2551.0, 2669.0, 2727.0, 2853.0, 2820.0, 2935.0, 3019.0], "textposition": "auto", "x": ["04/01/20", "04/02/20", "04/03/20", "04/04/20", "04/05/20", "04/06/20", "04/07/20", "04/08/20", "04/09/20", "04/10/20", "04/11/20", "04/12/20", "04/13/20", "04/14/20", "04/15/20", "04/16/20", "04/17/20", "04/18/20", "04/19/20", "04/20/20", "04/21/20", "04/22/20"], "y": [1087, 1128, 1292, 1458, 1501, 1501, 1532, 1663, 1840, 1978, 2092, 2239, 2285, 2306, 2419, 2551, 2669, 2727, 2853, 2820, 2935, 3019], "type": "bar", "uid": "5a342ca5-015b-459a-97fb-c1b76b4758d1"}], {"barmode": "stack", "showlegend": true, "title": {"text": "CovidOccitanieFrance"}, "xaxis": {"title": {"text": "Time"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("fb73edaa-115e-4768-8c9b-c4d948052bb2"));});</script>
